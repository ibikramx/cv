# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image as im

# %%
IMG=im.open('ab.jpg')
IMG=np.array(IMG)

# %%
IMG.shape
# Out:
# (1280, 576, 3)

# %%
img=np.zeros([1328, 248, 3], dtype=np.uint8)

# %%
 
import numpy as np
x = np.array([[10,20,30], [40,50,60]])
y = np.array([[100], [200]])
print(np.append(x, y, axis=1))
# Out:
# (1328, 248, 3)

# %%
box=np.append(IMG, img, axis=1)

# %%
plt.imshow(box)
