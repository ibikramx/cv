# %% [markdown]
# ##Edit img using numpy array

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %% [markdown]
# ###Read img using skimage

# %%
img=io.imread('ab.jpg')
img.shape
# Out:
# (1328, 1080, 3)

# %% [markdown]
# ###Show img using matplotlib

# %%
img[300:350]=[0,0,255]
plt.imshow(img)
