# %% [markdown]
# ####Read and show image using matplotlib

# %%
 import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('aa.jpg')
#print(img)

# %%
 imgplot = plt.imshow(img)

# %%
ab = mpimg.imread('ab.jpg')
plt.imshow(ab)

# %%
apple=ab[:,:,0].T
plt.imshow(apple)
